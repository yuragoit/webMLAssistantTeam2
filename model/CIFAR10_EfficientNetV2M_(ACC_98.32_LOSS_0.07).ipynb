# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns

import tensorflow as tf
from sklearn.metrics import confusion_matrix
from tensorflow.keras import optimizers
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, BatchNormalization, Flatten, Dropout, Activation, Input
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.applications import efficientnet_v2

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
#https://drive.google.com/file/d/12700bE-pomYKoVQ214VrpBoJ7akXcTpL/view?usp=share_link
# Out:
# Mounted at /content/drive

# %%
seed = 2023
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
(train_data, train_label), (test_data, test_label) = cifar10.load_data()
train_label = to_categorical(train_label)
test_label = to_categorical(test_label)
train_data = train_data.astype("float32")
test_data = test_data.astype("float32")
#EfficientNetV2 models expect their inputs to be float tensors of pixels with values in the [0-255] range.
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 13s 0us/step

# %%
X_train, X_valid, y_train, y_valid = train_test_split(train_data, train_label, random_state=seed, shuffle=True)

# %%
train_gen = ImageDataGenerator(rotation_range=15, width_shift_range=0.2, zoom_range=0.2, horizontal_flip=True)
train_generator = train_gen.flow(X_train, y_train, batch_size=32)

# %%
input_shape = (32, 32, 3) #Cifar10 image size
resized_shape = (224, 224, 3) #EfficientNetV2 model input shape
num_classes = 10

def build_model():
    inputs = Input(shape=input_shape)
    x = tf.keras.layers.Lambda(lambda image: tf.image.resize(image, resized_shape[:2]))(inputs) #Resize image to  size 224x224
    base_model = efficientnet_v2.EfficientNetV2M(include_top=False, input_shape=resized_shape, weights="imagenet")
    x = base_model(x)
    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.3)(x)
    outputs = Dense(num_classes, activation="softmax")(x)
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
model = build_model()

plateau = ReduceLROnPlateau(monitor="val_loss", factor=0.7, patience=1, verbose=1)
earlystopping = EarlyStopping(monitor="val_loss", patience=3, verbose=1)

model.compile(optimizer=optimizers.SGD(learning_rate=0.01, momentum=0.9),
              loss="categorical_crossentropy",
              metrics=["accuracy"])

model.summary()
print("\n")

history = model.fit(train_generator,
                    epochs=15,
                    validation_data=(X_valid, y_valid),
                    callbacks=[plateau, earlystopping]
                   )
print("\nTest Accuracy: ", accuracy_score(np.argmax(test_label, axis=1), np.argmax(model.predict(test_data), axis=1)))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-m_notop.h5
# 214201816/214201816 [==============================] - 12s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  lambda (Lambda)             (None, 224, 224, 3)       0
#
#  efficientnetv2-m (Functiona  (None, 7, 7, 1280)       53150388
#  l)
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1280)              0
#
#  dense (Dense)               (None, 10)                12810
#
# =================================================================
# Total params: 53,163,198
# Trainable params: 52,871,166
# Non-trainable params: 292,032
# _________________________________________________________________
#
#
# Epoch 1/15
# 1172/1172 [==============================] - 1142s 910ms/step - loss: 0.4402 - accuracy: 0.8525 - val_loss: 0.1414 - val_accuracy: 0.9526 - lr: 0.0100
# Epoch 2/15
# 1172/1172 [==============================] - 1061s 905ms/step - loss: 0.1776 - accuracy: 0.9407 - val_loss: 0.0951 - val_accuracy: 0.9677 - lr: 0.0100
# Epoch 3/15
# 1172/1172 [==============================] - 1061s 905ms/step - loss: 0.1177 - accuracy: 0.9611 - val_loss: 0.0879 - val_accuracy: 0.9706 - lr: 0.0100
# Epoch 4/15
# 1172/1172 [==============================] - 1057s 902ms/step - loss: 0.0931 - accuracy: 0.9682 - val_loss: 0.0826 - val_accuracy: 0.9749 - lr: 0.0100
# Epoch 5/15
# 1172/1172 [==============================] - 1061s 906ms/step - loss: 0.0760 - accuracy: 0.9746 - val_loss: 0.0814 - val_accuracy: 0.9734 - lr: 0.0100
# Epoch 6/15
# 1172/1172 [==============================] - ETA: 0s - loss: 0.0603 - accuracy: 0.9797
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.006999999843537807.
# 1172/1172 [==============================] - 1057s 902ms/step - loss: 0.0603 - accuracy: 0.9797 - val_loss: 0.0875 - val_accuracy: 0.9738 - lr: 0.0100
# Epoch 7/15
# 1172/1172 [==============================] - 1062s 906ms/step - loss: 0.0402 - accuracy: 0.9866 - val_loss: 0.0705 - val_accuracy: 0.9787 - lr: 0.0070
# Epoch 8/15
# 1172/1172 [==============================] - 1062s 906ms/step - loss: 0.0310 - accuracy: 0.9899 - val_loss: 0.0621 - val_accuracy: 0.9812 - lr: 0.0070
# Epoch 9/15
# 1172/1172 [==============================] - ETA: 0s - loss: 0.0257 - accuracy: 0.9920
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.004899999825283885.
# 1172/1172 [==============================] - 1062s 906ms/step - loss: 0.0257 - accuracy: 0.9920 - val_loss: 0.0724 - val_accuracy: 0.9798 - lr: 0.0070
# Epoch 10/15
# 1172/1172 [==============================] - ETA: 0s - loss: 0.0201 - accuracy: 0.9938
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0034300000406801696.
# 1172/1172 [==============================] - 1061s 906ms/step - loss: 0.0201 - accuracy: 0.9938 - val_loss: 0.0661 - val_accuracy: 0.9813 - lr: 0.0049
# Epoch 11/15
# 1172/1172 [==============================] - ETA: 0s - loss: 0.0141 - accuracy: 0.9954
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.002401000028476119.
# 1172/1172 [==============================] - 1063s 907ms/step - loss: 0.0141 - accuracy: 0.9954 - val_loss: 0.0664 - val_accuracy: 0.9825 - lr: 0.0034
# Epoch 11: early stopping
# 313/313 [==============================] - 66s 197ms/step
#
# Test Accuracy:  0.9832

# %%
fig, ax = plt.subplots(figsize=(12, 4), nrows=1, ncols=2)
ax[0].plot(history.history["loss"], c="r", label="train loss")
ax[0].plot(history.history["val_loss"], c="b", label="val loss")
ax[0].set_xlabel("Epoch")
ax[0].set_ylabel("Loss")
ax[0].legend()

ax[1].plot(history.history["accuracy"], c="r", label="train accuracy")
ax[1].plot(history.history["val_accuracy"], c="b", label="val accuracy")
ax[1].set_xlabel("Epoch")
ax[1].set_ylabel("Accuracy")
ax[1].legend()

# %%
model.save("model.keras")

# %%
loaded_model = tf.keras.models.load_model("model.keras")
x = tf.random.uniform((224, 224, 3))
assert np.allclose(model.predict(x), loaded_model.predict(x))
#

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
y_pred = model.predict(test_data)#10k images (10 classes x 1000 examples)
y_pred_classes = np.argmax(y_pred, axis = 1)
y_true = np.argmax(test_label, axis = 1)
conf_matrix = confusion_matrix(y_true, y_pred_classes) 

f,ax = plt.subplots(figsize = (12,12))
sns.heatmap(conf_matrix, annot=True, linewidths=0.1, linecolor="white", fmt='.0f', ax=ax)
plt.xlabel("Forecast Label")
plt.ylabel("Real Label")
plt.title("Confusion Matrix")

plt.show()
# Out:
# 313/313 [==============================] - 61s 194ms/step
